# %%
import pandas as pd 
import numpy as np 
import os
root_dir = '/home/pkpc/PROJECT/prototypical/classification'
df = pd.read_csv ('fer2013.csv')
df['Usage'].unique()
# Out:
# array(['Training', 'PublicTest', 'PrivateTest'], dtype=object)

# %%
df['pixelss']=[[int(y) for y in x.split()] for x in df['pixels']]

# %%
df_train=df[df['Usage']=='Training']
df_valid=df[df['Usage']=='PrivateTest']
df_test=df[df['Usage']=='PublicTest']

# %%
train_image_array = df_train.pixelss.to_numpy()  #all images for train
train_label_array = df_train.emotion.to_numpy()  #all labels for train

# %%
val_image_array = df_valid.pixelss.to_numpy()  #all images for train
val_label_array = df_valid.emotion.to_numpy()  #all labels for train

# %%
classes = df_valid.emotion.unique()  #all classes in trainset 
print(classes)
# Out:
# [0 5 6 4 2 3 1]

# %%
print(len(df_valid))
# Out:
# 3589

# %%
label_0_images=df_train.loc[df_train['emotion'] == 0,'pixels']
label_0_images = len(label_0_images)

label_2_images=df_train.loc[df_train['emotion'] == 2,'pixels']
label_2_images = len(label_2_images)

label_4_images=df_train.loc[df_train['emotion'] == 4,'pixels']
label_4_images = len(label_4_images)

label_6_images=df_train.loc[df_train['emotion'] == 6,'pixels']
label_6_images = len(label_6_images)

label_3_images=df_train.loc[df_train['emotion'] == 3,'pixels']
label_3_images = len(label_3_images)

label_5_images=df_train.loc[df_train['emotion'] == 5,'pixels']
label_5_images = len(label_5_images)

label_1_images =df_train.loc[df_train['emotion'] == 1,'pixels']
label_1_images = len(label_1_images )

#np.save(root_dir+'/train_0_imagess.npy', result)

# %%
images = []
for cls in classes:
    #print(cls)
    npy_dir = './valid_data/'+str(cls) + '/'
    if not os.path.exists(npy_dir):
        os.mkdir(npy_dir)
    result = df_valid.loc[df_valid['emotion'] == cls,'pixelss']
    #print(result)
    for index, values in result.items():
        cls = str(cls)
        index = str(index)
        print(type(values[0]))
        #np.save(npy_dir + str(index),values)
        #print(index)
    
        
"""    
for f in range(len(df_train)):
    img  = df_train.loc[df_train['emotion'] == cls,'pixels'] #.values[f]
    #images.append(img) np.save('class_train',values)
"""
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
result = df_train.loc[df_train['emotion'] == 1,'pixels']
print(result)
# Out:
# 299      126 126 129 120 110 168 174 172 173 174 170 15...
# 388      89 55 24 40 43 48 53 55 59 41 33 31 22 32 42 4...
# 416      204 195 181 131 50 50 57 56 66 98 138 161 173 ...
# 473      14 11 13 12 41 95 113 112 111 122 132 137 142 ...
# 533      18 25 49 75 89 97 100 100 101 103 105 107 107 ...
#                                ...
# 28260    41 38 40 34 29 39 34 50 109 184 220 231 233 23...
# 28332    53 64 78 81 81 81 80 79 78 77 78 80 82 85 87 9...
# 28390    2 0 85 139 197 220 219 225 229 231 232 230 225...
# 28598    22 20 18 21 38 48 55 58 59 66 73 84 93 94 91 8...
# 28650    228 173 153 154 145 112 79 66 112 179 199 210 ...
# Name: pixels, Length: 436, dtype: object

# %%
def process_batch(self, input_filenames,input_labels,classes, batch_sample_num):
    for k in range(batch_sample_num):
        class_idxs = list(range(0,self.way_num))
        random.shuffle

# %%
shot_num = 5
way_num = 2
episode_test_sample_num = 1
shuffle_images = False
num_sample_per_class = episode_test_sample_num + shot_num
npy_dir = './episode_filename_list/'
if not os.path.exists(npy_dir):
    os.mkdir(npy_dir)
npy_base_dir = npy_dir + str(shot_num) + 'shot_' + str(way_num) + 'way_' + str(episode_test_sample_num) + 'shuffled_' + str(shuffle_images) + '/'
if not os.path.exists(npy_base_dir):
    os.mkdir(npy_base_dir)
